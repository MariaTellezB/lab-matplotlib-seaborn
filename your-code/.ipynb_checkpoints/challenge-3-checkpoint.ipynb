# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable

titanic.select_dtypes(exclude=object).head(3)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250

# %%
#your code here- categorical variable

titanic.select_dtypes(exclude=['int','float']).head(3)
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here

plt.style.use('classic')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize']=(12,6)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here

titanic.Age.hist(bins = 50);

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here

plt.subplot(1,3,1)
titanic.Age.hist()

plt.subplot(1,3,2)
titanic.Age.hist(bins = 20)

plt.subplot(1,3,3)
titanic.Age.hist(bins = 50);

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

# The Bin parameter indicates the division of the data, the greater the number of bins, the greater the detail.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here

sns.displot(titanic.Age, bins = 30, kde = False, color = 'purple', alpha = 0.6);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way

titanic.Gender.value_counts().plot(kind = 'bar', alpha = 0.7)
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# your code here- 2nd way

sns.countplot(x='Gender', data = titanic, alpha = 0.5)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here

sns.countplot(x='Pclass', data = titanic, alpha = 0.5)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
t_s = titanic.describe()
t_s
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.879186     0.498854
# std     378.020061    0.486592     0.837836    13.448335     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    22.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.500000     0.000000
# 75%     982.000000    1.000000     3.000000    37.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1309.000000
# mean      0.385027    33.281086
# std       0.865560    51.741500
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
t_s.Age[1:].sort_values().plot(kind = 'barh', alpha = 0.5)
plt.xlabel('Age')
plt.ylabel('Statistics')
# Out:
# Text(0, 0.5, 'Statistics')

# %%
titanic.boxplot(column = 'Age')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here

#Themajority of the people were between >20 and < 40 years old. People older than 60 can be considered as outliers.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here

titanic.Age.plot(kind = 'kde');

# %%
sns.violinplot(x='Age', data=titanic);

# %%
sns.histplot(titanic.Age, color = 'blue', kde = True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here

#There was a considerable presence of babies, and little children. It shows the low presence of people older than 60 years, and reafirms 
# the high volumen of people between >= 20 adn <= 40.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way

plt.figure(figsize = (10, 6))
plt.scatter(titanic.Fare, titanic.Age, alpha=0.5)

plt.xlim([-1,300])
plt.ylim([-1,90])
plt.xlabel('Fare', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.grid(True)

# %%
# your code-2nd way
sns.lmplot(x = 'Fare', y = 'Age', data = titanic);

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here

sns.heatmap(titanic.corr(),cmap='BuPu', annot = True)
plt.title('Correlation matrix')
# Out:
# Text(0.5, 1.0, 'Correlation matrix')

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here

# Parch - SibSp
# Fare - Survived
# Fare - Age
# Fare - SibSp

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here

sns.boxplot(x='Pclass',y='Age',data=titanic, palette = 'magma')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here

g = sns.FacetGrid(data=titanic,col='Gender')
g.map(plt.hist,'Age');

# %%
g = sns.FacetGrid(data=titanic,col='Gender')
g.map(sns.histplot, 'Age', kde = True);
